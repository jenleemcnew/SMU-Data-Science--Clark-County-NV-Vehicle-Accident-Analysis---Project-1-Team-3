# %%
#importing necessary libraries 
import pandas as pd
import hvplot.pandas
import numpy as np
import json
import csv 
import matplotlib.pyplot as plt
import requests
import scipy.stats as st
from scipy.stats import linregress
import os

# from api_keys import geoapify_key # importing api key

# importing the csv file
# csvpath = os.path.join("traffic-crashes-1 (2).csv")

# with open(csvpath) as csvfile:
#     csvreader = csv.reader(csvfile, delimiter = ",")
#     csvheader = next(csvreader) 

traffic_data = pd.read_csv("traffic-crashes-1.csv")
traffic_data.columns
# Out:
# Index(['FID_1', 'OBJECTID', 'Crash_Seve', 'County', 'Crash_Date', 'Crash_Year',
#        'Crash_Time', 'Primary_St', 'Distance', 'Dir', 'Secondary_', 'Weather',
#        'Fatalities', 'Injured', 'Property_D', 'Injury_Typ', 'Crash_Type',
#        'Total_Vehi', 'V1_Type', 'V1_Dir', 'V1_Driver_', 'V1_Lane_Nu',
#        'V1_Action', 'V1_Driver1', 'V1_Drive_1', 'V1_Vehicle', 'V1_Most_Ha',
#        'V1_All_Eve', 'V2_Type', 'V2_Dir', 'V2_Driver_', 'V2_Lane_Nu',
#        'V2_Action', 'V2_Driver1', 'V2_Drive_1', 'V2_Vehicle', 'V2_Most_Ha',
#        'V2_All_Eve', 'First_Harm', 'Nonmotoris', 'Factors_Ro', 'Lighting',
#        'HWY_Factor', 'Agency', 'Accident_R', 'Pedalcycli', 'Pedestrian',
#        'Motorcycli', 'AnimalType', 'X', 'Y', 'OBJECTID_1', 'AREA', 'PERIMETER',
#        'WARD', 'CNTY_IS', 'SHADE', 'ACRES', 'SQ_MILES', 'AREA_1', 'LEN'],
#       dtype='object')

# %%
clean_traffic_data = traffic_data[["County",
                                   "Fatalities",
                                   "Injured",
                                   "Primary_St",
                                   "Crash_Seve",
                                   "Crash_Date",
                                   "Weather",
                                   "Crash_Type",
                                   "V1_Type",
                                   "V1_Driver1",
                                   "V1_Driver_",
                                   "Factors_Ro",
                                   "Lighting",
                                   "X",
                                   "Y"]].copy()
clean_traffic_data = pd.DataFrame(clean_traffic_data)
clean_traffic_data.head(5)
# Out:
#   County  Fatalities  Injured        Primary_St            Crash_Seve  \
# 0  CLARK         NaN        0  ECHELON POINT DR  PROPERTY DAMAGE ONLY
# 1  CLARK         NaN        1   GRAND CANYON DR          INJURY CRASH
# 2  CLARK         NaN        0     SKY POINTE DR  PROPERTY DAMAGE ONLY
# 3  CLARK         NaN        0            CC215S  PROPERTY DAMAGE ONLY
# 4  CLARK         NaN        0             US95N  PROPERTY DAMAGE ONLY
#
#    Crash_Date Weather     Crash_Type            V1_Type         V1_Driver1  \
# 0  01/01/2016   CLEAR       REAR-END  HATCHBACK, 4 DOOR  APPARENTLY NORMAL
# 1  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 4 DOOR  HAD BEEN DRINKING
# 2  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 2 DOOR  HAD BEEN DRINKING
# 3  01/01/2016   CLEAR  NON-COLLISION              SEDAN                NaN
# 4  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 4 DOOR  APPARENTLY NORMAL
#
#    V1_Driver_ Factors_Ro                    Lighting           X          Y
# 0          49        DRY                    DAYLIGHT -115.296856  36.282588
# 1          22        DRY          DARK - NO LIGHTING -115.305960  36.313917
# 2          22        DRY  DARK - CONTINUOUS LIGHTING -115.266269  36.279880
# 3           0        WET        DARK - SPOT LIGHTING -115.283121  36.278732
# 4          27        DRY          DARK - NO LIGHTING -115.312353  36.327534

# %%
clean_traffic_data[["County","Crash_Seve"]]
# Out:
#       County            Crash_Seve
# 0      CLARK  PROPERTY DAMAGE ONLY
# 1      CLARK          INJURY CRASH
# 2      CLARK  PROPERTY DAMAGE ONLY
# 3      CLARK  PROPERTY DAMAGE ONLY
# 4      CLARK  PROPERTY DAMAGE ONLY
# ...      ...                   ...
# 12715  CLARK  PROPERTY DAMAGE ONLY
# 12716  CLARK          INJURY CRASH
# 12717  CLARK          INJURY CRASH
# 12718  CLARK          INJURY CRASH
# 12719  CLARK  PROPERTY DAMAGE ONLY
#
# [12720 rows x 2 columns]

# %%
clean_traffic_data["Fatalities"] = clean_traffic_data["Fatalities"].fillna(0)
len(clean_traffic_data)
# Out:
# 12720

# %%
clean_traffic_data = clean_traffic_data.rename(columns={"Crash_Seve": "Crash Severity",
                                                        "Crash_Date": "Crash Date",
                                                        "Crash_Type": "Crash Type",
                                                        "V1_Type":"Vehicle_Type",
                                                        "V1_Driver1":"Impairment Level",
                                                        "V1_Driver_": "Age",
                                                        "Factors_Ro": "Road Conditions",
                                                        "X": "Latitude",
                                                        "Y": "Longitude"})
clean_traffic_data.head(3)
# Out:
#   County  Fatalities  Injured        Primary_St        Crash Severity  \
# 0  CLARK         0.0        0  ECHELON POINT DR  PROPERTY DAMAGE ONLY
# 1  CLARK         0.0        1   GRAND CANYON DR          INJURY CRASH
# 2  CLARK         0.0        0     SKY POINTE DR  PROPERTY DAMAGE ONLY
#
#    Crash Date Weather     Crash Type       Vehicle_Type   Impairment Level  \
# 0  01/01/2016   CLEAR       REAR-END  HATCHBACK, 4 DOOR  APPARENTLY NORMAL
# 1  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 4 DOOR  HAD BEEN DRINKING
# 2  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 2 DOOR  HAD BEEN DRINKING
#
#    Age Road Conditions                    Lighting    Latitude  Longitude
# 0   49             DRY                    DAYLIGHT -115.296856  36.282588
# 1   22             DRY          DARK - NO LIGHTING -115.305960  36.313917
# 2   22             DRY  DARK - CONTINUOUS LIGHTING -115.266269  36.279880

# %%
clean_traffic_data = clean_traffic_data.dropna()
clean_traffic_data.head(5)
# Out:
#   County  Fatalities  Injured        Primary_St        Crash Severity  \
# 0  CLARK         0.0        0  ECHELON POINT DR  PROPERTY DAMAGE ONLY
# 1  CLARK         0.0        1   GRAND CANYON DR          INJURY CRASH
# 2  CLARK         0.0        0     SKY POINTE DR  PROPERTY DAMAGE ONLY
# 4  CLARK         0.0        0             US95N  PROPERTY DAMAGE ONLY
# 6  CLARK         0.0        0          GASS AVE  PROPERTY DAMAGE ONLY
#
#    Crash Date Weather     Crash Type       Vehicle_Type  \
# 0  01/01/2016   CLEAR       REAR-END  HATCHBACK, 4 DOOR
# 1  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 4 DOOR
# 2  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 2 DOOR
# 4  01/01/2016   CLEAR  NON-COLLISION      SEDAN, 4 DOOR
# 6  01/01/2016   CLEAR          ANGLE      SEDAN, 2 DOOR
#
#                             Impairment Level  Age Road Conditions  \
# 0                          APPARENTLY NORMAL   49             DRY
# 1                          HAD BEEN DRINKING   22             DRY
# 2                          HAD BEEN DRINKING   22             DRY
# 4                          APPARENTLY NORMAL   27             DRY
# 6  HAD BEEN DRINKING: OTHER IMPROPER DRIVING   26             DRY
#
#                      Lighting    Latitude  Longitude
# 0                    DAYLIGHT -115.296856  36.282588
# 1          DARK - NO LIGHTING -115.305960  36.313917
# 2  DARK - CONTINUOUS LIGHTING -115.266269  36.279880
# 4          DARK - NO LIGHTING -115.312353  36.327534
# 6  DARK - CONTINUOUS LIGHTING -115.146042  36.160959

# %%
#Day or evening occurance
crash_stats_mean = clean_traffic_data.groupby("Crash Type")["Age"].mean()
crash_stats_med = clean_traffic_data.groupby("Crash Type")["Age"].median()
crash_stats_var = clean_traffic_data.groupby("Crash Type")["Age"].var()
crash_stats_std = clean_traffic_data.groupby("Crash Type")["Age"].std()
crash_stats_sem = clean_traffic_data.groupby("Crash Type")["Age"].sem()

age_stats = pd.DataFrame({"Mean age":crash_stats_mean,"Med age":crash_stats_med,"Var age":crash_stats_var,"Std age":crash_stats_std,"Sem age":crash_stats_sem})
age_stats
# Out:
#                         Mean age  Med age     Var age    Std age   Sem age
# Crash Type
# ANGLE                  39.127315     35.0  339.122315  18.415274  0.315773
# BACKING                42.213115     42.0  378.970492  19.467164  2.492515
# HEAD-ON                35.146341     29.0  357.478049  18.907090  2.952791
# NON-COLLISION          34.872903     30.0  245.258852  15.660742  0.397783
# REAR-END               35.080683     31.0  235.754999  15.354315  0.246913
# REAR-TO-REAR           34.695652     34.0  161.675889  12.715183  2.651299
# SIDESWIPE, MEETING     41.258929     40.0  324.878298  18.024381  1.703144
# SIDESWIPE, OVERTAKING  38.782958     37.0  255.001126  15.968755  0.640289
# UNKNOWN                36.352941     37.0  333.617647  18.265203  4.429962

# %%
age_stats_agg = clean_traffic_data.groupby("Crash Type")[["Age"]].agg(["mean","median","var","std","sem"])
round(age_stats_agg,2)
# Out:
#                          Age
#                         mean median     var    std   sem
# Crash Type
# ANGLE                  39.13   35.0  339.12  18.42  0.32
# BACKING                42.21   42.0  378.97  19.47  2.49
# HEAD-ON                35.15   29.0  357.48  18.91  2.95
# NON-COLLISION          34.87   30.0  245.26  15.66  0.40
# REAR-END               35.08   31.0  235.75  15.35  0.25
# REAR-TO-REAR           34.70   34.0  161.68  12.72  2.65
# SIDESWIPE, MEETING     41.26   40.0  324.88  18.02  1.70
# SIDESWIPE, OVERTAKING  38.78   37.0  255.00  15.97  0.64
# UNKNOWN                36.35   37.0  333.62  18.27  4.43

# %%
Weather_by_age = clean_traffic_data.groupby("Weather")["Age"].agg(["mean","median","var","std","sem"])
round(Weather_by_age,2)
# Out:
#                                          mean  median     var    std   sem
# Weather
# BLOWING SAND, SOIL, DIRT, SNOW          38.56    35.0  184.53  13.58  4.53
# CLEAR                                   36.82    33.0  281.73  16.78  0.19
# CLOUDY                                  37.43    34.0  298.94  17.29  0.47
# CLOUDY: BLOWING SAND, SOIL, DIRT, SNOW  35.00    35.0  162.00  12.73  9.00
# CLOUDY: FOG, SMOG, SMOKE                20.00    20.0     NaN    NaN   NaN
# CLOUDY: RAIN                            34.91    31.0  249.27  15.79  1.32
# CLOUDY: SEVERE CROSSWINDS               33.67    32.0  184.33  13.58  7.84
# FOG, SMOG, SMOKE                        42.25    44.5  377.58  19.43  9.72
# OTHER                                   26.33    22.0  124.33  11.15  6.44
# RAIN                                    34.93    31.0  218.50  14.78  0.87
# RAIN: BLOWING SAND, SOIL, DIRT, SNOW    47.00    47.0     NaN    NaN   NaN
# SEVERE CROSSWINDS                       43.80    43.0  258.70  16.08  7.19
# UNKNOWN                                 36.34    35.0  193.59  13.91  2.46

# %%
Impairment_by_age = clean_traffic_data.groupby("Impairment Level")["Age"].agg(["mean","median","var","std","sem"])
Impairment_by_age = pd.DataFrame(Impairment_by_age)
Impairment_by_age = round(Impairment_by_age,2)
Impairment_by_age = Impairment_by_age.dropna()
Impairment_by_age
# Out:
#                                                      mean  median      var  \
# Impairment Level
# APPARENTLY NORMAL                                   37.29    33.0   286.19
# DRUG INVOLVEMENT                                    34.37    31.0   190.75
# DRUG INVOLVEMENT: OTHER IMPROPER DRIVING            53.50    53.5   312.50
# FELL ASLEEP, FAINTED, FATIGUED, ETC.                33.86    27.5   269.25
# FELL ASLEEP, FAINTED, FATIGUED, ETC.: DRUG INVO...  29.83    25.0   161.37
# FELL ASLEEP, FAINTED, FATIGUED, ETC.: HAD BEEN ...  31.46    24.0   131.10
# FELL ASLEEP, FAINTED, FATIGUED, ETC.: OTHER IMP...  51.00    51.0   578.00
# HAD BEEN DRINKING                                   33.21    30.0   156.91
# HAD BEEN DRINKING: DRUG INVOLVEMENT                 31.80    30.0   157.76
# HAD BEEN DRINKING: DRUG INVOLVEMENT: OTHER IMPR...  41.50    41.5   684.50
# HAD BEEN DRINKING: OTHER IMPROPER DRIVING           31.44    27.5    86.65
# ILLNESS                                             53.66    59.0   363.53
# INATTENTION/DISTRACTED                              36.03    32.0   259.18
# INATTENTION/DISTRACTED: DRUG INVOLVEMENT            39.00    37.0    48.67
# INATTENTION/DISTRACTED: FELL ASLEEP, FAINTED, F...  61.33    61.0   650.33
# INATTENTION/DISTRACTED: HAD BEEN DRINKING           33.30    32.5    66.90
# INATTENTION/DISTRACTED: OTHER IMPROPER DRIVING      24.50    24.5    12.50
# OBSTRUCTED VIEW                                     44.00    42.0   468.80
# OTHER IMPROPER DRIVING                              33.01    30.0   366.22
# PHYSICAL IMPAIRMENT                                 42.00    37.0   198.50
# PHYSICAL IMPAIRMENT: FELL ASLEEP, FAINTED, FATI...  52.50    52.5  1404.50
# PHYSICAL IMPAIRMENT: HAD BEEN DRINKING              38.50    35.5   129.67
# PHYSICAL IMPAIRMENT: ILLNESS                        83.67    80.0   100.33
#
#                                                       std    sem
# Impairment Level
# APPARENTLY NORMAL                                   16.92   0.19
# DRUG INVOLVEMENT                                    13.81   1.16
# DRUG INVOLVEMENT: OTHER IMPROPER DRIVING            17.68  12.50
# FELL ASLEEP, FAINTED, FATIGUED, ETC.                16.41   1.50
# FELL ASLEEP, FAINTED, FATIGUED, ETC.: DRUG INVO...  12.70   5.19
# FELL ASLEEP, FAINTED, FATIGUED, ETC.: HAD BEEN ...  11.45   3.18
# FELL ASLEEP, FAINTED, FATIGUED, ETC.: OTHER IMP...  24.04  17.00
# HAD BEEN DRINKING                                   12.53   0.49
# HAD BEEN DRINKING: DRUG INVOLVEMENT                 12.56   1.76
# HAD BEEN DRINKING: DRUG INVOLVEMENT: OTHER IMPR...  26.16  18.50
# HAD BEEN DRINKING: OTHER IMPROPER DRIVING            9.31   1.55
# ILLNESS                                             19.07   2.50
# INATTENTION/DISTRACTED                              16.10   1.03
# INATTENTION/DISTRACTED: DRUG INVOLVEMENT             6.98   3.49
# INATTENTION/DISTRACTED: FELL ASLEEP, FAINTED, F...  25.50  14.72
# INATTENTION/DISTRACTED: HAD BEEN DRINKING            8.18   2.59
# INATTENTION/DISTRACTED: OTHER IMPROPER DRIVING       3.54   2.50
# OBSTRUCTED VIEW                                     21.65   5.41
# OTHER IMPROPER DRIVING                              19.14   1.01
# PHYSICAL IMPAIRMENT                                 14.09   4.70
# PHYSICAL IMPAIRMENT: FELL ASLEEP, FAINTED, FATI...  37.48  26.50
# PHYSICAL IMPAIRMENT: HAD BEEN DRINKING              11.39   5.69
# PHYSICAL IMPAIRMENT: ILLNESS                        10.02   5.78

# %%
Road_by_age = clean_traffic_data.groupby("Road Conditions")["Age"].agg(["mean","median","var","std","sem"])
Road_by_age = round(Road_by_age,2)
Road_by_age = Road_by_age.drop(labels=["ICE","OTHER"],axis=0,inplace=False)
Road_by_age
# Out:
#                  mean  median     var    std   sem
# Road Conditions
# DRY              37.0    33.0  286.11  16.91  0.18
# WET              35.1    31.0  231.83  15.23  0.51

# %%
accident_lighting = clean_traffic_data.groupby(["Lighting", "Weather"])["Lighting"].count()
accident_lighting = pd.DataFrame(accident_lighting)
accident_lighting
# Out:
#                                                                    Lighting
# Lighting                   Weather
# DARK - CONTINUOUS LIGHTING CLEAR                                        992
#                            CLOUDY                                       117
#                            CLOUDY: RAIN                                  18
#                            OTHER                                          1
#                            RAIN                                          28
#                            SEVERE CROSSWINDS                              1
# DARK - NO LIGHTING         BLOWING SAND, SOIL, DIRT, SNOW                 1
#                            CLEAR                                         76
#                            CLOUDY                                        10
#                            RAIN                                           9
# DARK - SPOT LIGHTING       BLOWING SAND, SOIL, DIRT, SNOW                 1
#                            CLEAR                                       1284
#                            CLOUDY                                       187
#                            CLOUDY: RAIN                                  25
#                            CLOUDY: SEVERE CROSSWINDS                      1
#                            FOG, SMOG, SMOKE                               2
#                            OTHER                                          1
#                            RAIN                                         126
#                            SEVERE CROSSWINDS                              2
#                            UNKNOWN                                        5
# DARK - UNKNOWN LIGHTING    CLEAR                                          5
#                            RAIN                                           1
#                            UNKNOWN                                        1
# DAWN                       CLEAR                                        124
#                            CLOUDY                                        11
#                            CLOUDY: RAIN                                   3
#                            RAIN                                           8
# DAYLIGHT                   BLOWING SAND, SOIL, DIRT, SNOW                 7
#                            CLEAR                                       5241
#                            CLOUDY                                       977
#                            CLOUDY: BLOWING SAND, SOIL, DIRT, SNOW         2
#                            CLOUDY: FOG, SMOG, SMOKE                       1
#                            CLOUDY: RAIN                                  95
#                            CLOUDY: SEVERE CROSSWINDS                      1
#                            FOG, SMOG, SMOKE                               2
#                            OTHER                                          1
#                            RAIN                                         113
#                            RAIN: BLOWING SAND, SOIL, DIRT, SNOW           1
#                            SEVERE CROSSWINDS                              2
#                            UNKNOWN                                       25
# DUSK                       CLEAR                                        143
#                            CLOUDY                                        34
#                            CLOUDY: RAIN                                   2
#                            CLOUDY: SEVERE CROSSWINDS                      1
#                            RAIN                                           2
#                            UNKNOWN                                        1
# OTHER                      CLOUDY: RAIN                                   1
# UNKNOWN                    CLEAR                                          2

# %%
# accident_lighting = accident_lighting.drop(labels=["OTHER","UNKNOWN"],axis=0,inplace=False)
# accident_lighting
#removed other and unknown

# %%
clean_traffic_data["day_night"]= clean_traffic_data["Lighting"].str[: 3]
clean_traffic_data
# Out:
#       County  Fatalities  Injured               Primary_St  \
# 0      CLARK         0.0        0         ECHELON POINT DR
# 1      CLARK         0.0        1          GRAND CANYON DR
# 2      CLARK         0.0        0            SKY POINTE DR
# 4      CLARK         0.0        0                    US95N
# 6      CLARK         0.0        0                 GASS AVE
# ...      ...         ...      ...                      ...
# 12714  CLARK         0.0        0  SR599N TO ANN RD INT90B
# 12715  CLARK         0.0        0             N BUFFALO DR
# 12716  CLARK         0.0        1       CLIFF SHADOWS PKWY
# 12717  CLARK         0.0        3             CHEYENNE AVE
# 12718  CLARK         0.0        2                 CRAIG RD
#
#              Crash Severity  Crash Date Weather     Crash Type  \
# 0      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR       REAR-END
# 1              INJURY CRASH  01/01/2016   CLEAR  NON-COLLISION
# 2      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR  NON-COLLISION
# 4      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR  NON-COLLISION
# 6      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR          ANGLE
# ...                     ...         ...     ...            ...
# 12714  PROPERTY DAMAGE ONLY  12/31/2016  CLOUDY       REAR-END
# 12715  PROPERTY DAMAGE ONLY  12/31/2016  CLOUDY  NON-COLLISION
# 12716          INJURY CRASH  12/31/2016   CLEAR  NON-COLLISION
# 12717          INJURY CRASH  12/31/2016  CLOUDY       REAR-END
# 12718          INJURY CRASH  12/31/2016  CLOUDY          ANGLE
#
#             Vehicle_Type                           Impairment Level  Age  \
# 0      HATCHBACK, 4 DOOR                          APPARENTLY NORMAL   49
# 1          SEDAN, 4 DOOR                          HAD BEEN DRINKING   22
# 2          SEDAN, 2 DOOR                          HAD BEEN DRINKING   22
# 4          SEDAN, 4 DOOR                          APPARENTLY NORMAL   27
# 6          SEDAN, 2 DOOR  HAD BEEN DRINKING: OTHER IMPROPER DRIVING   26
# ...                  ...                                        ...  ...
# 12714          CARRY-ALL                          APPARENTLY NORMAL   38
# 12715      SEDAN, 4 DOOR                          HAD BEEN DRINKING   24
# 12716        CONVERTIBLE       FELL ASLEEP, FAINTED, FATIGUED, ETC.   68
# 12717      SEDAN, 4 DOOR                          APPARENTLY NORMAL   65
# 12718      SEDAN, 2 DOOR                          HAD BEEN DRINKING   46
#
#       Road Conditions                    Lighting    Latitude  Longitude  \
# 0                 DRY                    DAYLIGHT -115.296856  36.282588
# 1                 DRY          DARK - NO LIGHTING -115.305960  36.313917
# 2                 DRY  DARK - CONTINUOUS LIGHTING -115.266269  36.279880
# 4                 DRY          DARK - NO LIGHTING -115.312353  36.327534
# 6                 DRY  DARK - CONTINUOUS LIGHTING -115.146042  36.160959
# ...               ...                         ...         ...        ...
# 12714             DRY                    DAYLIGHT -115.252436  36.262845
# 12715             DRY  DARK - CONTINUOUS LIGHTING -115.260731  36.203052
# 12716             DRY                    DAYLIGHT -115.329666  36.239294
# 12717             DRY  DARK - CONTINUOUS LIGHTING -115.322318  36.218215
# 12718             DRY  DARK - CONTINUOUS LIGHTING -115.251390  36.240358
#
#       day_night driver_impaired
# 0           DAY
# 1           DAR
# 2           DAR
# 4           DAR
# 6           DAR
# ...         ...             ...
# 12714       DAY
# 12715       DAR
# 12716       DAY
# 12717       DAR
# 12718       DAR
#
# [9694 rows x 17 columns]

# %%
accident_lighting = clean_traffic_data.groupby(["day_night"])["day_night"].count()
accident_lighting = pd.DataFrame(accident_lighting)
accident_lighting = accident_lighting.rename(columns={"day_night":"Count"}).reset_index()
accident_lighting
# Out:
#   day_night  Count
# 0       DAR   2894
# 1       DAW    146
# 2       DAY   6468
# 3       DUS    183
# 4       OTH      1
# 5       UNK      2

# %%
plt.figure(figsize=(6,6))
plt.bar(accident_lighting["day_night"],accident_lighting["Count"],align= "center")
plt.title("Number by Time of Day")
plt.xlabel("Time of Day")
plt.ylabel("Number of Accidents")
plt.xticks(rotation = 45)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
accident_int = clean_traffic_data.groupby(["Primary_St"])["Primary_St"].value_counts()
accident_int
# Out:
# Primary_St
# 28TH ST                2
# 30TH ST                1
# ALPINE PL              1
# ALTA DR               61
# AMY OLIVIA AVE         1
#                       ..
# WINDROSE POINT AVE     1
# WING ST                1
# WOODBRIDGE DR          1
# WOODLAND RIDGE ST      1
# WYANDOTTE ST           1
# Name: count, Length: 647, dtype: int64

# %%
accident_int = pd.DataFrame(accident_int)
accident_int = accident_int.sort_values("count", ascending=False)
accident_int.head(3)
# Out:
#             count
# Primary_St
# IR15N         960
# US95S         700
# US95N         596

# %%
accident_street_df = clean_traffic_data[[ "County", "Age", "Latitude","Longitude", "Primary_St"]].copy()
accident_street_df
# Out:
#       County  Age    Latitude  Longitude               Primary_St
# 0      CLARK   49 -115.296856  36.282588         ECHELON POINT DR
# 1      CLARK   22 -115.305960  36.313917          GRAND CANYON DR
# 2      CLARK   22 -115.266269  36.279880            SKY POINTE DR
# 4      CLARK   27 -115.312353  36.327534                    US95N
# 6      CLARK   26 -115.146042  36.160959                 GASS AVE
# ...      ...  ...         ...        ...                      ...
# 12714  CLARK   38 -115.252436  36.262845  SR599N TO ANN RD INT90B
# 12715  CLARK   24 -115.260731  36.203052             N BUFFALO DR
# 12716  CLARK   68 -115.329666  36.239294       CLIFF SHADOWS PKWY
# 12717  CLARK   65 -115.322318  36.218215             CHEYENNE AVE
# 12718  CLARK   46 -115.251390  36.240358                 CRAIG RD
#
# [9694 rows x 5 columns]

# %% [markdown]
# ### Narrow down the accident_street_df to show top 10 streets that had accidents

# %%
clean_accident_data_merge = pd.merge(accident_street_df, accident_int, how="left", on=["Primary_St", "Primary_St"])
clean_accident_data_merge = pd.DataFrame(clean_accident_data_merge)
clean_accident_data_merge.head(3)
# Out:
#   County  Age    Latitude  Longitude        Primary_St  count
# 0  CLARK   49 -115.296856  36.282588  ECHELON POINT DR      1
# 1  CLARK   22 -115.305960  36.313917   GRAND CANYON DR     14
# 2  CLARK   22 -115.266269  36.279880     SKY POINTE DR     20

# %%
age_count = clean_accident_data_merge.groupby("Age")["Age"].count()
age_count = age_count.sort_values(ascending=False)
age_count = age_count.head(10)
age_count = pd.DataFrame(age_count)
age_count = age_count
age_count = age_count.rename(columns={"Age":"Count"})
age_count = age_count.reset_index()
age_count = age_count.sort_values("Age",ascending=True)
age_count
# Out:
#    Age  Count
# 9   18    281
# 1   19    367
# 2   20    359
# 0   21    386
# 3   22    349
# 5   23    324
# 6   24    317
# 4   25    335
# 8   26    284
# 7   27    289

# %%
Age = age_count["Age"]
unit_labels = [f"{Age} years old" for age in age_count]
plt.pie(age_count["Count"], autopct='%1.f%%' ,labels=age_count["Age"])
plt.title("Top 10 Accident Ages ")
plt.xlabel("Age")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(age_count["Count"],labels=["Accidents"],
            flierprops={'marker':"o", 'markersize':10, 'markerfacecolor':'red'})
plt.show()

# %%
top_street_df = clean_accident_data_merge.loc[(clean_accident_data_merge["count"] >= 149)]
top_street_df = pd.DataFrame(top_street_df)
top_street_df
# Out:
#      County  Age    Latitude  Longitude   Primary_St  count
# 3     CLARK   27 -115.312353  36.327534        US95N    596
# 6     CLARK   23 -115.165380  36.150421        IR15N    960
# 8     CLARK   22 -115.166759  36.148856        IR15N    960
# 9     CLARK   46 -115.163842  36.152167        IR15N    960
# 10    CLARK   25 -115.165478  36.150309        IR15N    960
# ...     ...  ...         ...        ...          ...    ...
# 9676  CLARK   35 -115.115841  36.167172  EASTERN AVE    153
# 9680  CLARK   36 -115.173848  36.140799        IR15N    960
# 9682  CLARK   28 -115.175425  36.139011        IR15N    960
# 9683  CLARK   39 -115.174834  36.139682        IR15N    960
# 9686  CLARK   45 -115.150699  36.174275        US95S    700
#
# [3869 rows x 6 columns]

# %%
# Set parameters to search for a street

# params = {
#     "apiKey": geoapify_key,
#     "mode": "drive"
#     }

# for index, row in top_street_df.iterrows():
#     #get latidude and longitude from DataRFrame
#     lat = row["Latitude"]
#     lng = row ["Longitude"]

#     # Add waypoints current street's latitude and longitude to the params dictionary
#     params["waypoints"] = f"circle:{lng},{lat}"

# base_url = " https://api.geoapify.com/v1/mapmatching"

# # Make and API request using the params dictionaty
# street_address = requests.get(base_url, params=params)
    
# # Convert the API response to JSON format
# street_address = street_address.json()
    
# # Display sample data
# clean_accident_data

# %%
# define function to create linear regression plot
def linear_regression_plot(df, x_col, y_col, title, ylabel, xlabel, color="green"):
    x_data = df[x_col]
    y_data = df[y_col]

    linear_regression = linregress(x_data, y_data)
    plt.scatter(x_data, y_data, facecolors=color, edgecolors="black")

    linear_equation = linear_regression.slope * x_data + linear_regression.intercept

    plt.plot(x_data, linear_equation, "-", color="black")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    print(f"The r value is: {round(r,4)}")
    plt.show()

# %%
linear_regression_plot(clean_accident_data_merge,"Age","count","Age VS Accident Location","Accident", "Age",color="green")
# Out:
# The r value is: -0.0711

# %%
vehicle_type = clean_traffic_data.groupby("Vehicle_Type")["Age"].count().reset_index()
vehicle_type = vehicle_type.sort_values("Age",ascending=False)
vehicle_type = vehicle_type.head(15)
vehicle_type
# Out:
#          Vehicle_Type   Age
# 36      SEDAN, 4 DOOR  3992
# 6           CARRY-ALL  1584
# 31             PICKUP  1230
# 44                VAN   395
# 20  HATCHBACK, 4 DOOR   385
# 35      SEDAN, 2 DOOR   381
# 18    HARDTOP, 4 DOOR   348
# 43            UTILITY   232
# 34              SEDAN   170
# 19  HATCHBACK, 2 DOOR   141
# 17    HARDTOP, 2 DOOR   138
# 26         MOTORCYCLE   128
# 10        CONVERTIBLE    97
# 11              COUPE    73
# 37               SEMI    52

# %%
vehicle = vehicle_type['Vehicle_Type']
Total_accidents = vehicle_type['Age']

plt. figure(figsize=(15, 8))
plt.plot(vehicle,Total_accidents)
plt.xticks(rotation = 70)
plt.xlabel("Vehicle Type")
plt.ylabel("Accidents")
plt.show()

# %%
clean_traffic_data["driver_impaired"] = ""

# %%
for index, x in clean_traffic_data.iterrows():
    if clean_traffic_data.loc[index,"Impairment Level"] == "APPARENTLY NORMAL":
        clean_traffic_data.loc[index,"driver_impaired"] = "Normal"
    else:
        clean_traffic_data.loc[index,"driver_impaired"] = "Impaired"

# %%
clean_accident_data.head(5)
# Out:
#   County  Age    Latitude  Longitude        Primary_St  count
# 0  CLARK   49 -115.296856  36.282588  ECHELON POINT DR      1
# 1  CLARK   22 -115.305960  36.313917   GRAND CANYON DR     14
# 2  CLARK   22 -115.266269  36.279880     SKY POINTE DR     20
# 3  CLARK   27 -115.312353  36.327534             US95N    596
# 4  CLARK   26 -115.146042  36.160959          GASS AVE      9

# %%
accident_impaired = clean_traffic_data.groupby("driver_impaired")["driver_impaired"].count()
accident_impaired
# Out:
# driver_impaired
# Impaired    1747
# Normal      7947
# Name: driver_impaired, dtype: int64

# %%
impaired = clean_traffic_data["driver_impaired"].unique()
impaired_count = clean_traffic_data["driver_impaired"].value_counts()

dict1 = {"Impaired":impaired,
         "Impaired_cnt":impaired_count}

df1 = pd.DataFrame(dict1)

plt.pie(df1['Impaired_cnt'],autopct='%1.f%%',labels= df1['Impaired'])
plt.xlabel("Impaired vs Sober")
plt.show()

# %%
crash_type = clean_traffic_data.groupby("Crash Type")["Crash Type"].count()
crash_type = pd.DataFrame(crash_type)
crash_type = crash_type.rename(columns={"Crash Type":"Count"})
crash_type = crash_type.reset_index()
crash_type
# Out:
#               Crash Type  Count
# 0                  ANGLE   3401
# 1                BACKING     61
# 2                HEAD-ON     41
# 3          NON-COLLISION   1550
# 4               REAR-END   3867
# 5           REAR-TO-REAR     23
# 6     SIDESWIPE, MEETING    112
# 7  SIDESWIPE, OVERTAKING    622
# 8                UNKNOWN     17

# %%
plt.figure(figsize=(15,6))
plt.bar(crash_type["Crash Type"],crash_type["Count"],align= "center")
plt.title("Accidents by Type")
plt.xlabel("Collision Type")
plt.ylabel("Accidents")
plt.xticks(rotation = 60)
plt.show()

# %%
#What crash was most severe?
Crash_severity = clean_traffic_data.groupby("Crash Severity")["Crash Serverity"].count()
Crash_severity

clean_traffic_data.groupby("Crash Type")["Crash Type"].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[408], line 2
#       1 #What crash was most severe?
# ----> 2 Crash_severity = clean_traffic_data.groupby("Crash Severity")["Crash Serverity"].count()
#       3 Crash_severity
#
# File c:\Users\vallk\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1964, in DataFrameGroupBy.__getitem__(self, key)
#    1957 if isinstance(key, tuple) and len(key) > 1:
#    1958     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1959     # valid syntax, so don't raise
#    1960     raise ValueError(
#    1961         "Cannot subset columns with a tuple with more than one element. "
#    1962         "Use a list instead."
#    1963     )
# -> 1964 return super().__getitem__(key)
#
# File c:\Users\vallk\anaconda3\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Crash Serverity'

# %%
clean_traffic_data
# Out:
#       County  Fatalities  Injured               Primary_St  \
# 0      CLARK         0.0        0         ECHELON POINT DR
# 1      CLARK         0.0        1          GRAND CANYON DR
# 2      CLARK         0.0        0            SKY POINTE DR
# 4      CLARK         0.0        0                    US95N
# 6      CLARK         0.0        0                 GASS AVE
# ...      ...         ...      ...                      ...
# 12714  CLARK         0.0        0  SR599N TO ANN RD INT90B
# 12715  CLARK         0.0        0             N BUFFALO DR
# 12716  CLARK         0.0        1       CLIFF SHADOWS PKWY
# 12717  CLARK         0.0        3             CHEYENNE AVE
# 12718  CLARK         0.0        2                 CRAIG RD
#
#              Crash Severity  Crash Date Weather     Crash Type  \
# 0      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR       REAR-END
# 1              INJURY CRASH  01/01/2016   CLEAR  NON-COLLISION
# 2      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR  NON-COLLISION
# 4      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR  NON-COLLISION
# 6      PROPERTY DAMAGE ONLY  01/01/2016   CLEAR          ANGLE
# ...                     ...         ...     ...            ...
# 12714  PROPERTY DAMAGE ONLY  12/31/2016  CLOUDY       REAR-END
# 12715  PROPERTY DAMAGE ONLY  12/31/2016  CLOUDY  NON-COLLISION
# 12716          INJURY CRASH  12/31/2016   CLEAR  NON-COLLISION
# 12717          INJURY CRASH  12/31/2016  CLOUDY       REAR-END
# 12718          INJURY CRASH  12/31/2016  CLOUDY          ANGLE
#
#             Vehicle_Type                           Impairment Level  Age  \
# 0      HATCHBACK, 4 DOOR                          APPARENTLY NORMAL   49
# 1          SEDAN, 4 DOOR                          HAD BEEN DRINKING   22
# 2          SEDAN, 2 DOOR                          HAD BEEN DRINKING   22
# 4          SEDAN, 4 DOOR                          APPARENTLY NORMAL   27
# 6          SEDAN, 2 DOOR  HAD BEEN DRINKING: OTHER IMPROPER DRIVING   26
# ...                  ...                                        ...  ...
# 12714          CARRY-ALL                          APPARENTLY NORMAL   38
# 12715      SEDAN, 4 DOOR                          HAD BEEN DRINKING   24
# 12716        CONVERTIBLE       FELL ASLEEP, FAINTED, FATIGUED, ETC.   68
# 12717      SEDAN, 4 DOOR                          APPARENTLY NORMAL   65
# 12718      SEDAN, 2 DOOR                          HAD BEEN DRINKING   46
#
#       Road Conditions                    Lighting    Latitude  Longitude  \
# 0                 DRY                    DAYLIGHT -115.296856  36.282588
# 1                 DRY          DARK - NO LIGHTING -115.305960  36.313917
# 2                 DRY  DARK - CONTINUOUS LIGHTING -115.266269  36.279880
# 4                 DRY          DARK - NO LIGHTING -115.312353  36.327534
# 6                 DRY  DARK - CONTINUOUS LIGHTING -115.146042  36.160959
# ...               ...                         ...         ...        ...
# 12714             DRY                    DAYLIGHT -115.252436  36.262845
# 12715             DRY  DARK - CONTINUOUS LIGHTING -115.260731  36.203052
# 12716             DRY                    DAYLIGHT -115.329666  36.239294
# 12717             DRY  DARK - CONTINUOUS LIGHTING -115.322318  36.218215
# 12718             DRY  DARK - CONTINUOUS LIGHTING -115.251390  36.240358
#
#       day_night driver_impaired
# 0           DAY          Normal
# 1           DAR        Impaired
# 2           DAR        Impaired
# 4           DAR          Normal
# 6           DAR        Impaired
# ...         ...             ...
# 12714       DAY          Normal
# 12715       DAR        Impaired
# 12716       DAY        Impaired
# 12717       DAR          Normal
# 12718       DAR        Impaired
#
# [9694 rows x 17 columns]
